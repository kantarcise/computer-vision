# %% [markdown]
# ## Recap 💕
#
# In the previous lecture, we talked about the foundational research on Vision before computers.
#
# We set the goal to discover the bridge between **camera obscura** and the **digital camera.**
#
# In this video/notebook, we will explore about analog and digital cameras and try to understand the technology that are used in our phones today.

# %% [markdown]
# ## One Intermediate Step - Analog Cameras ✨
#
# Cameras are tools that freeze a single moment.
#
# And before we had digital cameras, we had analog cameras which were based on the same principles of camera obscura.
#
# ![Film Camera](../img/digital_cameras/film_camera.jpg)
#
# [Source](https://www.snappysnaps.co.uk/blog/how-to-use-film-cameras)
#
# **“Analogue”** comes from a Greek word meaning “in proportion” or “similar.”
#
# In the case of cameras, "analog" means that the entire camera captures an image of the film that is a continuous, seamless representation of the world. Similar to the way our eyes view the world.
#
# It is like a drawing or painting made up of many small pieces connected together.
#
# Analog cameras, in their simplest form, consist of 5 parts.
#
# * **Lens**: It is the round cam part located on the front of the camera. It helps focus light from the Earth onto a special film at the core of the camera.
# * **Aperture**: Aperture is an opening that primarily limits light propagated through the camera.
# * **Film**: This is like a special paper that captures the picture. It's inside the camera and when you take a photo, light from the earth hits the film and a photo is created!
# * **Shutter**: It is like a curtain that opens and closes to let in light. When you press the button to take a photo, the shutter opens and then closes again.
# * **Film Roll**: . Where the photo was saved. After a photo, it moves a bit to prepare for the next photo.
#
# ![Parts of Film Camera](../img/digital_cameras/filmCameraParts.png)
#
# Here is a color negative film that has to be processed before printed out as a photograph.
#
# ![Films](../img/digital_cameras/film_examples.jpg)
#
# [Source - Thedarkroomlab](https://www.instagram.com/p/CCCGSyfpRFM/?igshid=172ylr7fk9v68)

# %% [markdown]
# ## Digital Cameras 📱
#
# Let's say you noticed a wonderful view, and wanted to share it with your loved ones.
#
# Usually you do not just get your analog camera, take a photo, print it and send it to them by mail.
#
# You use your phone take photos instantly and share them right away with the internet. You can even make changes to the photo, color, shadows, filters and more.
#
# ![Take a Pic!](../img/digital_cameras/takeAPicture.jpg)
#
# We owe this to digital cameras.
#
# Digital cameras work like regular cameras with a few differences:
#
# Like a traditional camera, it has an array of lenses that focus light to compose a scene.
#
# But instead of focusing this light on a piece of film, it is focused on a semiconductor device that records the light electronically. That's the big difference.
#
# Nowadays, we have digital cameras everywhere.
#
# This has many advantages:
#
# -   it gives us **instant** photographs
# -   allows us to **edit** our pictures
# -   makes it easier for us to **share** photographs using smartphones.
#
# ## But, how do they do that ?  🤔

# %% [markdown]
# ## How exactly a digital image is made? 🤔
#
# - Light from the thing you are photographing zooms into the camera lens.
# - This incoming "picture" hits the image sensor chip, which breaks it up into millions of pixels.
# - The sensor measures the color and brightness of each pixel and stores it as a number.
# - Your digital photograph is effectively an enormously long string of numbers describing the exact details of each pixel it contains.
#
# ![Digital Images](../img/digital_cameras/howDigitalImagesMade.jpg)
#
# [Source: Canon](https://www.canon.com.tr/pro/infobank/image-sensors-explained/)

# %% [markdown]
# ## Lenses
#
# Just like a analog camera, it has a **series of lenses** that focus light to make an image of a scene.
#
# ![Lens](../img/digital_cameras/lens.jpeg)
#
# [Source](https://www.canon.com.tr/lenses/lens-type/)
#
# A lens is not a **single lens.**
#
# All of the lenses have different purposes, solving problems like diffraction or helping image stabilization and focusing.
#
# ![Lens Cutaway](../img/digital_cameras/aperture-lens-cutaway.jpg)
#
# An illustration of the typical structure of a lens.
#
# Light entering the lens (1) passes through the front element (2), the rear element (5) and various lens groups (3) in between – some with optical elements designed to correct problems such as diffraction, some for image stabilisation in IS lenses, and some for focusing.
#
# The aperture blades (4) control how much of the light reaches the camera sensor.
#
# [Source](https://www.canon.com.tr/pro/infobank/aperture/)

# %% [markdown]
# ## Image Sensors
#
# These are **semiconductor devices** that records light electronically.
#
# ![Image Sensor](../img/digital_cameras/canoneosc70Inside.jpg)
#
# [Source](https://www.canon.com.tr/pro/infobank/image-sensors-explained/)
#
# There are 2 main types of image sensors used today.
#
# In the past, the image sensor employed by most digital cameras was a charge coupled device (CCD).
#
# The surface of a CCD Sensors is packed with photodiodes, each of which senses light and accumulates electrical charge in accordance with the strength of light that strikes it.
#
# They were used in NASA's interplanetary spacecraft. But they had problems when exposed to radiation and power dissipation was high. To use the CCD there were a lot of other parts needed (like ADC) that were bulky and power-hungry. [Source](https://ericfossum.com/Publications/Papers/2023%20IEEE%2075th%20Anniversary%20of%20the%20Transistor%20-%202023%20-%20Nathan%20-%20The%20Invention%20and%20Development%20of%20CMOS%20Image%20Sensors.pdf)
#
# To address these problems, another approach was suggested, the CMOS!
#
# Most of cameras today use complementary metal oxide semiconductor (CMOS) technology instead. [Source](https://electronics.howstuffworks.com/cameras-photography/digital/digital-camera1.htm)
#
# [Recommended read](https://ericfossum.com/Publications/Papers/2023%20IEEE%2075th%20Anniversary%20of%20the%20Transistor%20-%202023%20-%20Nathan%20-%20The%20Invention%20and%20Development%20of%20CMOS%20Image%20Sensors.pdf) about CMOS image sensors.

# %% [markdown]
# ## Power of the Customer! ✅
#
# With the promise of **lower power consumption** and **higher integration for smaller components**, CMOS designers focused efforts on imagers for mobile phones, the highest volume image sensor application in the world.
#
# An enormous amount of investment was made to develop and fine tune CMOS imagers and the fabrication processes that manufacture them.
#
# As a result of this investment, we witnessed great improvements in image quality, even as pixel sizes shrank.
#
# Therefore, in the case of high volume consumer area and line scan imagers, based on almost every performance parameter imaginable, CMOS imagers outperform CCDs.
#
# ![Comparison](../img/digital_cameras/ccdVScmos.png)
#
# [Source](https://www.teledynedalsa.com/en/learn/knowledge-center/ccd-vs-cmos/)
#
# ## How do they really work ?
#
# Both image sensors use photodiodes, if you want to discover more about how they work, you can go [here.](https://global.canon/en/technology/s_labo/light/003/04.html)
#
# ![Photodiodes](../img/digital_cameras/photodiodes.gif)
#
# In simple, photodiodes are semiconductors that are used to convert light into electrical energy.
#
# ­Although numerous differences exist between the two sensors, they both play the same role in the camera -- they turn light into electricity.
#
# For the purpose of understanding how a digital camera works, you can think of them as nearly identical devices.

# %% [markdown]
# ## Capturing Color
#
# A limitation of individual photosites is that they are unable to perceive color.
#
# Instead, they only measure the **overall brightness** of the light that hits them. To capture a full-color image, most camera sensors employ a filtering system that breaks down light into its three primary colors.
#
# By recording the intensity of each of these colors, the camera can then combine them to produce a complete and vibrant color spectrum.
#
# ### One Solution - Beam Splitter
#
# A beam splitter can be used to receive color!
#
# To illustrate this process, imagine light entering the camera as water flowing through a pipe.
#
# The beam splitter acts as a divider, channeling an identical amount of "water" into three separate pipes, each leading to a distinct sensor.
#
# Although each sensor receives an identical view of the image, the filters ensure that each sensor only responds to one of the three primary colors.
#
# The key benefit of this approach is that the camera captures all three colors at every pixel location, resulting in a more accurate and detailed color representation.
#
# However, a drawback of this method is that it often leads to cameras that are larger in size and more expensive. [Source](https://electronics.howstuffworks.com/cameras-photography/digital/digital-camera4.htm)
#
# ![Beam Splitter](../img/digital_cameras/beam_splitter.jpg)
#
# ### Another Solution - Filters!
#
# A more cost-effective and practical approach to capturing primary colors is to affix a color filter array directly over each individual photosite.
#
# By dividing the sensor into a mosaic of red, blue, and green pixels, it's possible to gather sufficient information from the surrounding area to make highly accurate estimates of the true color at each location.
#
# This process, known as **interpolation**, involves analyzing the data from neighboring pixels and making an informed inference about the color at a given point ([Source](https://electronics.howstuffworks.com/cameras-photography/digital/digital-camera5.htm)).
#
# ![Filters](../img/digital_cameras/demosaicing.png)
#
# [Source](https://www.bitcraze.io/2020/07/ai-deck-sees-in-color/)
#
# ## Why is there a lot of green in Bayer ? 🤔
#
# The Bayer filter pattern is 50% green, 25% red and 25% blue.
#
# The reason there is more green is that both silicon and the human eye are **most responsive around the green** wavelengths.
#
# ![Bayer Filter](../img/digital_cameras/bayerFilter.png)
#
# [Source](https://en.wikipedia.org/wiki/Bayer_filter)
#
# The raw output of Bayer-filter cameras is referred to as a **Bayer pattern image**.
#
# Since each pixel is filtered to record only one of three colors, the data from each pixel cannot fully specify each of the red, green, and blue values on its own.
#
# To obtain a full-color image, various **demosaicing** algorithms can be used to interpolate a set of complete red, green, and blue values for each pixel.
#
# These algorithms make use of the surrounding pixels of the corresponding colors to estimate the values for a particular pixel.

# %% [markdown]
# ## Detail in Images - Resolution
#
# The amount of detail that the camera can capture is called the resolution, and it is measured in pixels.
#
# The more pixels a camera has, the more detail it can capture and the larger pictures can be without becoming blurry or "grainy."
#
# ![Resolution Comparison](../img/digital_cameras/YouTube-resolution-comparison.jpg)
#
# [Source - Wikipedia](https://en.wikipedia.org/wiki/File:YouTube-resolution-comparison.jpg)

# %% [markdown]
# ## And much more to discover!
#
# There are much more to learn about what plays a role in making a digital photograph.
#
# Things like **aperture**, **shutter speed**, **ISO** and **focal length**.
#
# **Aperture** controls the amount of light entering through the lens.
#
# **Shutter speed** dictates the duration of light hitting the sensor.
#
# **ISO** sets the camera sensor's sensitivity to light.
#
# Image down below will give you a rough idea, with A being ISO, B being Shutter Speed and C being Aperture.
#
# ![Exposure Triangle](../img/digital_cameras/exposureTriangle.jpg)
#
# The type of image you can produce is also dependent on **focal length**.
#
# The focal length is the distance in millimetres between the lens and surface of sensor.
#
# ![Focal Length](../img/digital_cameras/focalLength.jpg)
#
# You can learn more about them, [here](https://www.canon.com.tr/pro/infobank/aperture/) and [here.](https://www.canon.com.tr/pro/infobank/understanding-focal-length/#what-is-focal-length)

# %% [markdown]
# ## Storing Digital Photos
#
# No matter what type of storage they use, all digital cameras need lots of room for pictures.
#
# There are different formats that we can store images, like JPEG, RAW, TIFF, PNG and HEIC.
#
# ![Image Formats](../img/digital_cameras/ImageFormats.jpg)
#
# [Source](https://99designs.com/blog/tips/image-file-types/)
#
# Some of them are differentiated by how they are compressed, either lossless or lossy.
#
# To understand where to use which, here is another [wonderful source.](https://www.hostinger.in/tutorials/best-image-formats)

# %% [markdown]
# ## The iPhone Camera 📱
#
# In 2007 the iPhone advertised a 2-megapixel camera that could capture standard definition 480p resolution. With no video capability or front-facing camera the original iPhone had no filmmaking capacity at all.
#
# The iPhone 6 released in 2014 was the first big leap for iPhone into the world of filmmaking. Previous models had posed useable for home video or photos with friends, but the iPhone 6 introduced camera quality equivilant to that of older model DSLR cameras of the time. Unlike previous models, iPhone 6 could capture 1080p 60 frames-per-second.
#
# Pair that with the introduction of digital stabilization that adjusted to movement as well as allowing for add-on lenses to be attached to the camera and this iPhone was the biggest technical leap for filmmaking since the introduction of Steadicam. [Source](https://student.hca.westernsydney.edu.au/units/wp_102264/wp-content/uploads/2020/10/Jeydan_Usta_Inside_Out.pdf)
#
# iPhone 11 Pro added a transformative triple-camera system that made capturing quality images with higher light-sensitivity significantly easier. Included was an ultrawide lense with 13mm focal length, 120 degree field of view and a 12-megapixel sensor, riveling professional cameras and lenses. The resolution capability was four times better than the iPhone 6 with the addition of shooting in 4K with high dynamic range at 60 framesper-second.
#
# ![three Cameras](../img/digital_cameras/threecams.jpg)
#
# [Source](https://techcrunch.com/2019/09/10/why-does-the-new-iphone-11-pro-have-3-cameras/)

# %% [markdown]
# ## Why are there 3 cameras on a Phone ?  🤔
#
# The motherboard of the phone is much smaller.
#
# All the camera hardware is smaller.
#
# A single camera is limited, and companies wanted to showcase features like optical zoom, portrait mode.
#
# Multiple cameras, provides different features.
#
# The **ultrawide camera** gives you the ability to shoot at $0.5x$ with a wider field of view.
#
# The **telephoto camera** give you the ability to make optical zoom.
#
# ![More Cameras, More Fun](../img/digital_cameras/11proCamera.jpg)
#
# [Source](https://9to5mac.com/2021/09/05/use-ultra-wide-camera-iphone-11-and-12/)
#
# And all cameras talk to each other, so they already know the correct exposure and tone mapping settings when you switch between them.
#
# This applies to images and videos. [Source](https://www.gsmarena.com/apple_iphone_15_plus-review-2621p5.php)
#
# ## What kind of filter does the iPhone use ? 🤔
#
# ### Quad Bayer Filter on iPhone 15
#
# The Quad Bayer structure means four adjacent pixels are clustered with the same-color filters.
#
# What really changes is not the filter but the sensor behind it – these new sensors put four pixels behind each color square instead of just one. You can read more about it [here](https://www.gsmarena.com/quad_bayer_sensors_explained-news-37459.php)
#
# In this way, high sensitivity and high resolution can be achieved in one sensor.
#
# It can, for example, prevent resolution loss in a low-illuminance environment and produce low-noise nightscape photos.
#
# ![Quad Bayer](../img/digital_cameras/quadBayer.png)
#
# [Source](https://www.sony-semicon.com/en/technology/mobile/quad-bayer-coding.html)
#
# The Image Sensor Technology keeps getting better!

# %% [markdown]
# ## Summary
#
# Today we made the transition from camera obscura to analog cameras, and then we discovered the working principles of digital cameras.
#
# As an extra, we explored the basics from the iPhone camera, as they will be one of the sources in our applications in the upcoming weeks.
#
# In the next notebook, we will explore how the visual cortex works, discovering how images are computed in the mind.
#
# See you in the next video.
#
# #### Extras
#
# [Here](https://www.youtube.com/watch?app=desktop&v=LWxu4rkZBLw) is a wonderfull video about digital images.
